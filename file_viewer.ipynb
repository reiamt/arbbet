# %%
import pandas as pd

pd.read_csv('football_games.csv')
# Out:
#     Unnamed: 0                      Team1                    Team2  \
# 0            0          Perry Lakes Hawks       Lakeside Lightning
# 1            1                 Mersin BSB            Cagdas Bodrum
# 2            2  Demir Insaat Buyukcekmece          Pinar Karsiyaka
# 3            3                 Leeuwarden                ZZ Leiden
# 4            4                Lietkabelis                 Juventus
# 5            5                TenerifeESP      Hapoel JerusalemISR
# 6            6             F.C. Barcelona         Monbus Obradoiro
# 7            7                  AS Monaco                  Le Mans
# 8            8          Unicaja MalagaESP  Telekom Baskets BonnGER
# 9            9            Valencia Basket              Real Madrid
# 10          10            New York Knicks               Miami Heat
# 11          11      Golden State Warriors       Los Angeles Lakers
# 12          12         Philadelphia 76ers           Boston Celtics
#
# ...
